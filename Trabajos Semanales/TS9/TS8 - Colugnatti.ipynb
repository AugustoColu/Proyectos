# %% [markdown]
# #### Análisis y Procesamiento de Señales
#
# ---
#
# # Tarea Semanal N°9
# ## *Filtrado no lineal*
#
# #### Augusto Colugnatti

# %% [markdown]
# ---
#
# ## Introducción teórica
#
# ---

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ## Conclusiones
